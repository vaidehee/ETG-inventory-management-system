# %%
import json

# %%
fd = open("record.json",'r')
r = fd.read()
fd.close()

record = json.loads(r)

# %%
js = json.dumps(record)

fd = open("record.json",'w')

fd.write(js)

fd.close()

# %% [markdown]
# # BILLING

# %%
import uuid
import time
print("*****************************************")
print("               DALVI'S STORE                ")
print("*****************************************")
print("            pn no:022-1234567890            ")
print("20b, Willingdon Colony, Santacruz (W), Mumbai, Maharashtra 400054 · ~15.3 km")
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print("* WELCOME TO OUR GROCERY STORE*")
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print("")
print("=========================================")
print("TRANSACTION ID:" ,end="")
UI=uuid.uuid1()
print(UI)
print("Date and Time :",time.ctime())

print("-------------------------------------")
print("")
print("*** YOUR BILL ***")
print("")
name=input("name:")


billinginjson={}
sales=[]
time=time.ctime()
m=0
n =int(input("how many items do you wanna buy?:"))
for i in range (n):

 userinput_product=str(input("Enter the product ID: "))
 userinput_quantity=int(input("Enter the quantity of product: "))
 print("Product:", record[userinput_product]['product name'])
 print("price:",record[userinput_product]['price'])    
 print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
 print("cost :",(record[userinput_product]['price']*(userinput_quantity)))
 m= m+((record[userinput_product]['price'])*(userinput_quantity))
 print("````````````````````````````````")
 billinginjson["Time"]=time
 billinginjson['Name']=name
 billinginjson['Product']=record[userinput_product]['product name']
 billinginjson['Quantity']=userinput_quantity
 billinginjson["Total Amount"]=str(m)
 billinginjson["Left in stock"]=record[userinput_product]['quantity']
 sales=[]
 sales.append(billinginjson)
 
print(" ")
print("-------------")
print("your bill",m)
print("=============")
print(" ")
if(m>0):
    if m<=5000:
        disc = m*0.05
    elif m<=15000:
        disc=m*0.12
    elif m<=25000:
        disc=0.2 * m
    else:
        disc=0.3 * m
    
    print("*************************")
    print("YOUR DISCOUNT IS : ",disc)
    print("NET PAY : ",m-disc)
    print("**************************")
    billinginjson["Discount Amount"]=str(m-disc)
else:
    print("Invalid Amount")
    
 



print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print("********🙏🏻THANK YOU FOR your GREAT TIME🙏🏻********")
print("=====================================================")
print("")
print("-------------------------------------")
print("......🌸DO VISIT AGAIN🌸......")
print("--------------------------------------")
record[userinput_product]['quantity'] = record[userinput_product]['quantity'] - (int(userinput_quantity))
# Out:
# *****************************************
#                DALVI'S STORE
# *****************************************
#             pn no:022-1234567890
# 20b, Willingdon Colony, Santacruz (W), Mumbai, Maharashtra 400054 · ~15.3 km
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# * WELCOME TO OUR GROCERY STORE*
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ...
# TRANSACTION ID:d61001b5-0ef3-11ec-9499-f80dac7fce72
# Date and Time : Mon Sep  6 14:51:37 2021
# -------------------------------------
#
# *** YOUR BILL ***
#
# name:VAIDEHEE DALVI
# how many items do you wanna buy?:2
# Enter the product ID: 1111135
# Enter the quantity of product: 50
# Product: lexi pen
# price: 20
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# cost : 1000
# ````````````````````````````````
# Enter the product ID: 1111112
# Enter the quantity of product: 5
# Product: foil box
# price: 229
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# cost : 1145
# ````````````````````````````````
#
# -------------
# your bill 2145
# ...
#
# ...

# %% [markdown]
# # SALES

# %%
js1 = json.dumps(sales)
fd1 = open("sales.json",'w')
fd1.write(js1)
fd1.close()

fd1 = open('sales.json','r')
sl=fd1.read()
fd1.close()
sales=json.loads(sl)
