# %%
record={1111101:{"id":"1","product name":"kitkat" , "type":"chocolate" ,"weight":"500" , "quantity":200, "mfg date":"1 july 2020" , "exp date": "2 july 2022"  , "price":10 },
        1111102:{"id":"2","product name":"coriander" , "type":"herbs" , "weight":"1000gm"  , "quantity":40,"mfg date":"8aug2021" , "exp date": "5aug2021" , "price":75 },
        1111103:{"id":"3","product name":"maggie" ,"type":"snacks" ,"weight":"280gm" ,"quantity":100, "mfg date": "8july2021" , "exp date":"9june2022" , "price":43},
        1111104:{"id":"4","product name":"tomato sauce" ,"type":"sauces" ,"weight":"950gm"  ,"quantity":155, "mfg date": "10oct2021" , "exp date":"9jan2022" , "price":113},
        1111105:{"id":"5","product name":"oregano jar" ,"type":"spices/herbs" ,"weight":"150gm" ,"quantity":260, "mfg date": "8july2021" , "exp date":"9june2022" , "price":12},
        1111106:{"id":"6","product name":"bread pouch" ,"type":"bakery" ,"weight":"400gm" ,"quantity":490, "mfg date": "8july2020" , "exp date":"9dec2021" , "price":65},
        1111107:{"id":"7","product name":"ginger in kg" ,"type":"spices/herbs" ,"weight":"100gm" ,"quantity":10000,   "mfg date" : "-" , "exp date":"-" , "price":18},
        1111108:{"id":"8","product name":"soya sauce " ,"type":"sauces" ,"weight":"190gm" ,"quantity":180,   "mfg date" : "8oct2021" , "exp date":"9june2022" , "price":49},
        1111109:{"id":"9","product name":"garlic in kg" ,"type":"spices/herbs" ,"weight":"250gm" ,"quantity":5000,   "mfg date" : "-" , "exp date":"9june2022" , "price":49},
        1111110:{"id":"10","product name":" pav bag" ,"type":"bakery" ,"weight":"200gm" ,"quantity":1800,   "mfg date" : "29may2021" , "exp date":"9june2021" , "price":40},
        1111111:{"id":"11","product name":"soya sauce" ,"type":"sauces" ,"weight":"190gm" ,"quantity":180,   "mfg date" : "8oct2021" , "exp date":"9june2022" , "price":49},
        1111112:{"id":"12","product name":"foil box" ,"type":"paper/plastic" ,"weight":"10820metres" ,"quantity":650,   "mfg date" : "8july2021" , "exp date":"-" , "price":229},
        1111113:{"id":"13","product name":"lays packet" ,"type":"snacks" ,"weight":"72.5gm" ,"quantity":600,   "mfg date" : "8july2021" , "exp date":"9june2022" , "price":229},
        1111114:{"id":"14","product name":"bisleri " ,"type":"drink" ,"weight":"1litre" ,"quantity":800,   "mfg date" : "8july2021" , "exp date":"use before 12 months" , "price":229},
        1111115:{"id":"15","product name":"bagels packet" ,"type":"bakery" ,"weight":"250gm(pack of 3)" ,"quantity":800,   "mfg date" : "8july2021" , "exp date":"9aug2021" , "price":49},
        1111116:{"id":"16","product name":"cumin pouch" ,"type":"spice/herbs" ,"weight":"100gm" ,"quantity":8000,   "mfg date" : "8july2021" , "exp date":"9june2022" , "price":56},
        1111117:{"id":"17","product name":"bru coffee " ,"type":"coffee beans baverage" ,"weight":"100gm" ,"quantity":600,   "mfg date" : "8july2021" , "exp date":"9july2020" , "price":290},
        1111118:{"id":"18","product name":"soda packet" ,"type":"soda" ,"weight":"100gm" ,"quantity":800,   "mfg date" : "7jan2021" , "exp date":"9oct2022" , "price":39},
        1111119:{"id":"19","product name":"red label " ,"type":"tea" ,"weight":"1kg" ,"quantity":324,   "mfg date" : "8july2021" , "exp date":"9oct2023" , "price":650},
        1111120:{"id":"20","product name":"black pepper" ,"type":"spices/herbs" ,"weight":"200gm" ,"quantity":9000,   "mfg date" : "8july2021" , "exp date":"-" , "price":149},
        1111121:{"id":"21","product name":"butter carton" ,"type":"dairy/frozen products" ,"weight":"100gm" ,"quantity":650,   "mfg date" : "8july2021" , "exp date":"9oct2022" , "price":51},
        1111122:{"id":"22","product name":"cheese slice" ,"type":"dairy/frozen products" ,"weight":"663gm" ,"quantity":800,   "mfg date" : "8july2021" , "exp date":"10july2022" , "price":441},
        1111123:{"id":"23","product name":"yogurt pack" ,"type":"dairy/frozen product" ,"weight":"100ml" ,"quantity":650,   "mfg date" : "8july2021" , "exp date":"31sept2021" , "price":99},
        1111124:{"id":"24","product name":"kurkure " ,"type":"snacks" ,"weight":"250ml" ,"quantity":900,   "mfg date" : "8nov2021" , "exp date":"9dec2021" , "price":20},
        1111125:{"id":"25","product name":"toothpaste" ,"type":"personal" ,"weight":"80gm" ,"quantity":600,   "mfg date" : "3may2021" , "exp date":"3may2022" , "price":55},
        1111126:{"id":"26","product name":"vegetable oil" ,"type":"oils" ,"weight":"1litre" ,"quantity":2000,   "mfg date" : "8aug2021" , "exp date":"8aug2022" , "price":172},
        1111127:{"id":"27","product name":"coconut oil" ,"type":"oils" ,"weight":"600ml" ,"quantity":900,   "mfg date" : "8july2021" , "exp date":"9july2023" , "price":209},
        1111128:{"id":"28","product name":"thumps up " ,"type":"drinks" ,"weight":"2 litre" ,"quantity":800,   "mfg date" : "8june2021" , "exp date":"26oct2022" , "price":95},
        1111129:{"id":"29","product name":"olive oil " ,"type":"oils" ,"weight":"2 litre" ,"quantity":950,   "mfg date" : "19 aug2021" , "exp date":"31dec2022" , "price":899},
        1111130:{"id":"30","product name":"shampoo" ,"type":"personal" ,"weight":"650ml" ,"quantity":100 ,   "mfg date" : "30dec2020" , "exp date":"31dec2022" , "price":407},
        
       
    
}

# %%
import json

# %%
js= json.dumps(record)

# %%
js
# Out:
# '{"1111101": {"id": "1", "product name": "kitkat", "type": "chocolate", "weight": "500", "quantity": 200, "mfg date": "1 july 2020", "exp date": "2 july 2022", "price": 10}, "1111102": {"id": "2", "product name": "coriander", "type": "herbs", "weight": "1000gm", "quantity": 40, "mfg date": "8aug2021", "exp date": "5aug2021", "price": 75}, "1111103": {"id": "3", "product name": "maggie", "type": "snacks", "weight": "280gm", "quantity": 100, "mfg date": "8july2021", "exp date": "9june2022", "price": 43}, "1111104": {"id": "4", "product name": "tomato sauce", "type": "sauces", "weight": "950gm", "quantity": 155, "mfg date": "10oct2021", "exp date": "9jan2022", "price": 113}, "1111105": {"id": "5", "product name": "oregano jar", "type": "spices/herbs", "weight": "150gm", "quantity": 260, "mfg date": "8july2021", "exp date": "9june2022", "price": 12}, "1111106": {"id": "6", "product name": "bread pouch", "type": "bakery", "weight": "400gm", "quantity": 490, "mfg date": "8july2020", "exp d
# ...

# %%
record
# Out:
# {1111101: {'id': '1',
#   'product name': 'kitkat',
#   'type': 'chocolate',
#   'weight': '500',
#   'quantity': 200,
#   'mfg date': '1 july 2020',
#   'exp date': '2 july 2022',
#   'price': 10},
#  1111102: {'id': '2',
#   'product name': 'coriander',
#   'type': 'herbs',
#   'weight': '1000gm',
#   'quantity': 40,
#   'mfg date': '8aug2021',
#   'exp date': '5aug2021',
#   'price': 75},
#  1111103: {'id': '3',
#   'product name': 'maggie',
#   'type': 'snacks',
#   'weight': '280gm',
#   'quantity': 100,
#   'mfg date': '8july2021',
#   'exp date': '9june2022',
#   'price': 43},
#  1111104: {'id': '4',
#   'product name': 'tomato sauce',
#   'type': 'sauces',
#   'weight': '950gm',
#   'quantity': 155,
#   'mfg date': '10oct2021',
#   'exp date': '9jan2022',
#   'price': 113},
#  1111105: {'id': '5',
#   'product name': 'oregano jar',
#   'type': 'spices/herbs',
#   'weight': '150gm',
#   'quantity': 260,
#   'mfg date': '8july2021',
#   'exp date': '9june2022',
# ...

# %%
fd = open("record.json",'r')
r = fd.read()
fd.close()

record = json.loads(r)

# %%
js = json.dumps(record)

# %%
fd = open("record.json",'w')

fd.write(js)

fd.close()

# %%
record
# Out:
# {'1111101': {'id': '1',
#   'product name': 'kitkat',
#   'type': 'chocolate',
#   'weight': '500',
#   'quantity': 200,
#   'mfg date': '1 july 2020',
#   'exp date': '2 july 2022',
#   'price': 10},
#  '1111102': {'id': '2',
#   'product name': 'coriander',
#   'type': 'herbs',
#   'weight': '1000gm',
#   'quantity': 40,
#   'mfg date': '8aug2021',
#   'exp date': '5aug2021',
#   'price': 75},
#  '1111103': {'id': '3',
#   'product name': 'maggie',
#   'type': 'snacks',
#   'weight': '280gm',
#   'quantity': 100,
#   'mfg date': '8july2021',
#   'exp date': '9june2022',
#   'price': 43},
#  '1111104': {'id': '4',
#   'product name': 'tomato sauce',
#   'type': 'sauces',
#   'weight': '950gm',
#   'quantity': 155,
#   'mfg date': '10oct2021',
#   'exp date': '9jan2022',
#   'price': 113},
#  '1111105': {'id': '5',
#   'product name': 'oregano jar',
#   'type': 'spices/herbs',
#   'weight': '150gm',
#   'quantity': 260,
#   'mfg date': '8july2021',
#   'exp date': '9june2022',
# ...

# %% [markdown]
# # VIEW MY CART

# %%
print("welcome to our store")
view=input("view my cart:")
print("************************")
print("~~~~~~~~~~~~~~~~INVENTORY MANAGEMENT~~~~~~~~~~~~~~~~~")
print("************************")
        
        

print("ID\t\tProduct\t\t\t\t\t\t Cost\tQuantity\t\t\t")
print("")
for i in record:
    print(record[i]['id'],"\t\t", 
          record[i]['product name'],"\t\t\t\t\t",
          record[i]['price'],"\t",
          record[i]['quantity'])
# Out:
# welcome to our store
# view my cart:y
# ************************
# ~~~~~~~~~~~~~~~~INVENTORY MANAGEMENT~~~~~~~~~~~~~~~~~
# ************************
# ID		Product						 Cost	Quantity
#
# 1 		 kitkat 					 68 	 200
# 2 		 coriander 					 133 	 40
# 3 		 maggie 					 101 	 100
# 4 		 tomato sauce 					 171 	 155
# 5 		 oregano jar 					 70 	 260
# 6 		 bread pouch 					 65 	 490
# 7 		 ginger in kg 					 18 	 10000
# 8 		 soya sauce  					 49 	 180
# 9 		 garlic in kg 					 49 	 5000
# 10 		  pav bag 					 40 	 1800
# 11 		 soya sauce 					 49 	 185
# 12 		 foil box 					 229 	 655
# 13 		 lays packet 					 229 	 600
# 14 		 bisleri  					 287 	 800
# 15 		 bagels packet 					 49 	 800
# 16 		 cumin pouch 					 56 	 8000
# 17 		 bru coffee  					 290 	 600
# 18 		 soda packet 					 39 	 800
# 19 		 red label  					 650 	 324
# 20 		 black pepper 					 149 	 9000
# 21 		 butter carton 					 51 	 708
# 22 		 cheese slice 					 441 	 800
# 23 		 yogurt pack 					 99 	 650
# ...

# %%
record['1111144']['id']= '44'

# %% [markdown]
# # ADD PRODUCT DETAILS TO RECORD

# %%
d =int(input("how much product you wanna add?:"))
for i in range(d):
 product_id =str(input("Enter product id:"))
 sr_no=str(input("enter sr no:"))
 product_name = str(input("Enter name:"))
 type = str(input("Enter type:"))
 weight = str(input("Enter weight:"))
 quantity= int(input("enter quantity:"))
 mfg_date =str(input("enter mfg date:"))
 exp_date=str(input("enter exp date:"))
 price=int(input("enter price:"))



 record[product_id] = {'id':sr_no,'product name': product_name, 'type':type,  'quantity': quantity, 'mfg date': mfg_date  ,'exp date': exp_date,'price': price}
 print("products added in record")

        


js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# how much product you wanna add?:20
# Enter product id:1111131
# enter sr no:31
# Enter name:maza bottle
# Enter type:sauce
# Enter weight:50gm
# enter quantity:500
# enter mfg date:june2021
# enter exp date:june2023
# enter price:50
# products added in record
# Enter product id:1111132
# enter sr no:32
# Enter name:jam bottle
# Enter type:50gm
# Enter weight:50gm
# enter quantity:600
# enter mfg date:june2021
# enter exp date:june2023
# enter price:60
# products added in record
# Enter product id:1111133
# enter sr no:33
# Enter name:spinach
# Enter type:vegetable
# Enter weight:50gm
# enter quantity:50
# enter mfg date:-
# enter exp date:-
# enter price:60
# products added in record
# Enter product id:1111134
# enter sr no:34
# Enter name:turmeric
# Enter type:spices
# Enter weight:1kg
# enter quantity:200
# enter mfg date:june2021
# enter exp date:june2023
# enter price:60
# products added in record
# Enter product id:1111135
# enter sr no:35
# Enter name:lexi pen
# Enter type:pen
# ...

# %%
record
# Out:
# {'1111101': {'id': '1',
#   'product name': 'kitkat',
#   'type': 'chocolate',
#   'weight': '500',
#   'quantity': 200,
#   'mfg date': '1 july 2020',
#   'exp date': '2 july 2022',
#   'price': 10},
#  '1111102': {'id': '2',
#   'product name': 'coriander',
#   'type': 'herbs',
#   'weight': '1000gm',
#   'quantity': 40,
#   'mfg date': '8aug2021',
#   'exp date': '5aug2021',
#   'price': 75},
#  '1111103': {'id': '3',
#   'product name': 'maggie',
#   'type': 'snacks',
#   'weight': '280gm',
#   'quantity': 100,
#   'mfg date': '8july2021',
#   'exp date': '9june2022',
#   'price': 43},
#  '1111104': {'id': '4',
#   'product name': 'tomato sauce',
#   'type': 'sauces',
#   'weight': '950gm',
#   'quantity': 155,
#   'mfg date': '10oct2021',
#   'exp date': '9jan2022',
#   'price': 113},
#  '1111105': {'id': '5',
#   'product name': 'oregano jar',
#   'type': 'spices/herbs',
#   'weight': '150gm',
#   'quantity': 260,
#   'mfg date': '8july2021',
#   'exp date': '9june2022',
# ...

# %% [markdown]
# # ADDING NEW QUANTITY TO OLD QUANTITY

# %%
c =int(input("how much quantity you wanna add?:"))
for i in range(c):
 product_id = str(input("Enter product ID:"))
 newquantityinproducts = int(input("Enter the quantity of products u wanna add:"))
 record[product_id]['quantity']= newquantityinproducts+int(record[product_id]['quantity'])
 print("quantity is added in products")
 print("The quantity after adding new quantity is:"+ str(record[product_id]['quantity']))
# Out:
# how much quantity you wanna add?:10
# Enter product ID:1111133
# Enter the quantity of products u wanna add:5
# quantity is added in products
# The quantity after adding new quantity is:55
# Enter product ID:1111134
# Enter the quantity of products u wanna add:32
# quantity is added in products
# The quantity after adding new quantity is:232
# Enter product ID:1111137
# Enter the quantity of products u wanna add:5
# quantity is added in products
# The quantity after adding new quantity is:605
# Enter product ID:1111111
# Enter the quantity of products u wanna add:5
# quantity is added in products
# The quantity after adding new quantity is:185
# Enter product ID:1111136
# Enter the quantity of products u wanna add:4
# quantity is added in products
# The quantity after adding new quantity is:64
# Enter product ID:1111137
# Enter the quantity of products u wanna add:35
# quantity is added in products
# The quantity after adding new quantity is:640
# Enter product ID:1111112
# ...

# %% [markdown]
# # NEW PRICE AFTER PRICEINCREASE

# %%
d=int(input("how many products prize u want to add:"))
for i in range(d):
 product_id = str(input("Enter product ID:"))
 newprizeinproducts = int(input("Enter the prize of products yoy want to add:"))
 record[product_id]['price']= newquantityinproducts+int(record[product_id]['price'])
 print("cost is added in products")
 print("THE price AFTER ADDING NEW price IS:"+ str(record[product_id]['price']))
# Out:
# how many products prize u want to add:20
# Enter product ID:1111133
# Enter the prize of products yoy want to add:1
# cost is added in products
# THE price AFTER ADDING NEW price IS:118
# Enter product ID:1111131
# Enter the prize of products yoy want to add:2
# cost is added in products
# THE price AFTER ADDING NEW price IS:108
# Enter product ID:1111132
# Enter the prize of products yoy want to add:3
# cost is added in products
# THE price AFTER ADDING NEW price IS:118
# Enter product ID:1111134
# Enter the prize of products yoy want to add:6
# cost is added in products
# THE price AFTER ADDING NEW price IS:118
# Enter product ID:1111135
# Enter the prize of products yoy want to add:2
# cost is added in products
# THE price AFTER ADDING NEW price IS:78
# Enter product ID:1111139
# Enter the prize of products yoy want to add:2
# cost is added in products
# THE price AFTER ADDING NEW price IS:193
# Enter product ID:1111150
# Enter the prize of products yoy want to add:2
# ...

# %%
record
# Out:
# {'1111101': {'id': '1',
#   'product name': 'kitkat',
#   'type': 'chocolate',
#   'weight': '500',
#   'quantity': 200,
#   'mfg date': '1 july 2020',
#   'exp date': '2 july 2022',
#   'price': 68},
#  '1111102': {'id': '2',
#   'product name': 'coriander',
#   'type': 'herbs',
#   'weight': '1000gm',
#   'quantity': 40,
#   'mfg date': '8aug2021',
#   'exp date': '5aug2021',
#   'price': 133},
#  '1111103': {'id': '3',
#   'product name': 'maggie',
#   'type': 'snacks',
#   'weight': '280gm',
#   'quantity': 100,
#   'mfg date': '8july2021',
#   'exp date': '9june2022',
#   'price': 101},
#  '1111104': {'id': '4',
#   'product name': 'tomato sauce',
#   'type': 'sauces',
#   'weight': '950gm',
#   'quantity': 155,
#   'mfg date': '10oct2021',
#   'exp date': '9jan2022',
#   'price': 171},
#  '1111105': {'id': '5',
#   'product name': 'oregano jar',
#   'type': 'spices/herbs',
#   'weight': '150gm',
#   'quantity': 260,
#   'mfg date': '8july2021',
#   'exp date': '9june2022',
# ...
